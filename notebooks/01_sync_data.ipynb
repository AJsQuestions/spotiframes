# %% [markdown]
# # 🔄 Spotify Library Sync
#
# This notebook downloads your Spotify library and saves it locally for offline analysis.
#
# **What it does:**
# - ✅ Fetches all your playlists (owned only)
# - ✅ Fetches your Liked Songs (❤️ master playlist)
# - ✅ Downloads track and artist metadata
# - ✅ Saves everything to `../data/` as parquet files
# - ✅ Incremental updates (only fetches changes)
#
# **Run this first!** Then use `02_analyze_library.ipynb` for analysis.

# %% [markdown]
# ## 1️⃣ Setup
#
# Install dependencies and configure credentials.

# %%
# Install dependencies (run once)
# %pip install -q pandas spotipy pyarrow tqdm python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Add project to path
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"✅ Project root: {PROJECT_ROOT}")
# Out:
# ✅ Project root: /Users/aryamaan/Desktop/Projects/spotim8

# %%
import os
from dotenv import load_dotenv

# Load credentials from ../.env file
env_path = PROJECT_ROOT / ".env"
if env_path.exists():
    load_dotenv(env_path)
    print(f"✅ Loaded credentials from {env_path}")
else:
    print(f"⚠️  No .env file found at {env_path}")
    print("   Create one with SPOTIPY_CLIENT_ID, SPOTIPY_CLIENT_SECRET, SPOTIPY_REDIRECT_URI")

# Verify credentials are set
client_id = os.environ.get("SPOTIPY_CLIENT_ID", "")
if client_id and client_id != "YOUR_CLIENT_ID":
    print(f"   Client ID: {client_id[:8]}...")
else:
    print("   ❌ SPOTIPY_CLIENT_ID not set!")
# Out:
# ✅ Loaded credentials from /Users/aryamaan/Desktop/Projects/spotim8/.env
#    Client ID: 8263fcc5...

# %% [markdown]
# ## 2️⃣ Connect to Spotify
#
# This will open a browser window for authentication on first run.

# %%
from spotim8 import Spotim8, set_response_cache
from spotim8.catalog import CacheConfig

# Data directory (stores downloaded data)
DATA_DIR = PROJECT_ROOT / "data"
DATA_DIR.mkdir(exist_ok=True)

# Enable API response caching to avoid rate limits
# Cached responses are reused for 1 hour
API_CACHE_DIR = DATA_DIR / ".api_cache"
set_response_cache(API_CACHE_DIR, ttl=3600)

# Initialize client with caching
sf = Spotim8.from_env(
    progress=True,
    cache=CacheConfig(dir=DATA_DIR)
)

print(f"✅ Connected to Spotify!")
print(f"📁 Data will be saved to: {DATA_DIR}")
# Out:
# 📦 API response cache enabled: /Users/aryamaan/Desktop/Projects/spotim8/data/.api_cache (TTL: 3600s)
# ✅ Connected to Spotify!
# 📁 Data will be saved to: /Users/aryamaan/Desktop/Projects/spotim8/data

# %% [markdown]
# ## 3️⃣ Sync Your Library
#
# This fetches your playlists and tracks. First run may take a few minutes.

# %%
# Sync library (incremental - only fetches changes)
stats = sf.sync(
    owned_only=True,           # Only your playlists, not followed ones
    include_liked_songs=True   # Include Liked Songs as master playlist
)

print(f"\n📊 Sync complete!")
# Out:
# 🔄 Starting library sync...
# Your application has reached a rate/request limit. Retry will occur after: 30771 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Sync library (incremental - only fetches changes)
# ----> 2 stats = sf.sync(
#       3     owned_only=True,           # Only your playlists, not followed ones
#       4     include_liked_songs=True   # Include Liked Songs as master playlist
#       5 )
#       7 print(f"\n📊 Sync complete!")
#
# File ~/Desktop/Projects/spotim8/spotim8/client.py:163, in Spotim8.sync(self, force, owned_only, include_liked_songs)
#     160 stats = {"playlists_checked": 0, "playlists_updated": 0, "tracks_added": 0, "liked_songs": 0}
#     162 # Always refresh playlist list (includes Liked Songs)
# --> 163 pls = self.playlists(force=True, include_liked_songs=include_liked_songs)
#     165 # Filter to owned only
#     166 if owned_only:
#
# File ~/Desktop/Projects/spotim8/spotim8/client.py:350, in Spotim8.playlists(self, force, include_liked_songs)
#     347     if df is not None:
#     348         return df
# --> 350 first = self._rate_limited(self.sp.current_user_playlists, limit=50)
#     351 items = self._paginate(first, "items")
#     353 rows = []
#
# File ~/Desktop/Projects/spotim8/spotim8/client.py:93, in Spotim8._rate_limited(self, func, *args, **kwargs)
#      91 def _rate_limited(self, func: Callable, *args, **kwargs):
#      92     """Wrapper for rate-limited API calls."""
# ---> 93     return rate_limited_call(func, *args, delay=self._request_delay, **kwargs)
#
# File ~/Desktop/Projects/spotim8/spotim8/ratelimit.py:117, in rate_limited_call(func, delay, max_retries, verbose, use_cache, *args, **kwargs)
#     115 try:
#     116     time.sleep(delay)
# --> 117     result = func(*args, **kwargs)
#     119     # Cache successful response
#     120     if use_cache and RESPONSE_CACHE_DIR:
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:658, in Spotify.current_user_playlists(self, limit, offset)
#     652 def current_user_playlists(self, limit=50, offset=0):
#     653     """ Get current user playlists without required getting his profile
#     654         Parameters:
#     655             - limit  - the number of items to return
#     656             - offset - the index of the first item to return
#     657     """
# --> 658     return self._get("me/playlists", limit=limit, offset=offset)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:321, in Spotify._get(self, url, args, payload, **kwargs)
#     318 if args:
#     319     kwargs.update(args)
# --> 321 return self._internal_call("GET", url, payload, kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     262 logger.debug(f"Sending {method} to {url} with Params: "
#     263              f"{args.get('params')} Headers: {headers} and Body: {args.get('data')!r}")
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#     272     results = response.json()
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:942, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     939     return response
#     941 response.drain_conn()
# --> 942 retries.sleep(response)
#     943 log.debug("Retry: %s", url)
#     944 return self.urlopen(
#     945     method,
#     946     url,
#    (...)
#     959     **response_kw,
#     960 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/util/retry.py:359, in Retry.sleep(self, response)
#     350 """Sleep between retry attempts.
#     351
#     352 This method will respect a server's ``Retry-After`` response header
#    (...)
#     355 this method will return immediately.
#     356 """
#     358 if self.respect_retry_after_header and response:
# --> 359     slept = self.sleep_for_retry(response)
#     360     if slept:
#     361         return
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/util/retry.py:338, in Retry.sleep_for_retry(self, response)
#     336 retry_after = self.get_retry_after(response)
#     337 if retry_after:
# --> 338     time.sleep(retry_after)
#     339     return True
#     341 return False
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4️⃣ Build Full Data Tables
#
# Now let's build all the detailed tables (tracks, artists, etc.)

# %%
# Fetch all data tables (uses cache if available)
print("📥 Building data tables...\n")

playlists = sf.playlists()
print(f"✅ Playlists: {len(playlists):,}")

playlist_tracks = sf.playlist_tracks()
print(f"✅ Playlist-track links: {len(playlist_tracks):,}")

tracks = sf.tracks()
print(f"✅ Unique tracks: {len(tracks):,}")

track_artists = sf.track_artists()
print(f"✅ Track-artist links: {len(track_artists):,}")

artists = sf.artists()
print(f"✅ Artists: {len(artists):,}")

# Build the wide table (everything joined)
library = sf.library_wide()
print(f"✅ Library wide table: {len(library):,} rows")
# Out:
# 📥 Building data tables...
#
# ✅ Playlists: 555
# ✅ Playlist-track links: 31,164
# ✅ Unique tracks: 5,232
# ✅ Track-artist links: 8,414
# ✅ Artists: 2,597
# ✅ Library wide table: 31,207 rows

# %% [markdown]
# ## 5️⃣ View Your Data

# %%
# Show status summary
sf.print_status()
# Out:
# ==================================================
#         SPOTIFYFRAMES DATA STATUS
# ==================================================
# 📁 Cache directory: /Users/aryamaan/Desktop/Projects/spotim8_repo/data
# 👤 User: 31iol2qamank24owygxo7kpq533y
# 🕐 Last sync: 2025-12-19T01:17:45.099294+00:00
#
# 📊 Cached data:
#    • Playlists: 555
#    • Playlist tracks: 31,164
#    • Unique tracks: 5,232
#    • Track-artist links: 8,414
#    • Artists: 2,597
# ==================================================

# %%
# Preview playlists
print("📂 Your Playlists:")
playlists[["name", "track_count", "is_liked_songs", "is_owned"]].head(15)
# Out:
# 📂 Your Playlists:
#                                                name  track_count  \
# 0                                    ❤️ Liked Songs         5077
# 1                                          Trapsoul            8
# 2                                            Dec’25          112
# 3                                           Trance             7
# 4                                ADHD Study Music 🧠          300
# 5                                       DarkThots🌑🔪           28
# 6                 Funky / Hip Hop / Chilled / Beats          361
# 7   Funky hip hop soul grooves. Music for the soul          1498
# 8                                2013-2015 EDM Hits           54
# 9                               Pop ig dont deep it          174
# 10                                          Revenge          664
# 11                   Soft Spanish Jazz / Bossa Nova           52
# 12                                           Nov’25          382
# 13                                       InMyRoom 💽          271
# 14                         80/90s Japanese City Pop           56
#
#     is_liked_songs  is_owned
# 0             True      True
# 1            False      True
# 2            False      True
# 3            False      True
# 4            False     False
# 5            False      True
# 6            False     False
# 7            False     False
# 8            False     False
# 9            False      True
# 10           False     False
# 11           False     False
# 12           False      True
# 13           False      True
# 14           False     False

# %%
# Preview tracks
print("🎵 Sample Tracks:")
tracks[["name", "album_name", "popularity", "duration_ms"]].head(10)
# Out:
# 🎵 Sample Tracks:
#                                               name  \
# 0                            Chamber Of Reflection
# 1                               Can't Feel My Face
# 2                               Walking On A Dream
# 3                                     Teenage Blue
# 4                       we fell in love in october
# 5                                              fwb
# 6                                     Cult Classic
# 7  VIRGINIA Boy (feat. Tyler, The Creator) - Remix
# 8                              When I Was Your Man
# 9                                            Don't
#
#                                           album_name  popularity  duration_ms
# 0                                         Salad Days          83       231723
# 1                          Beauty Behind The Madness          84       213520
# 2      Walking On A Dream (10th Anniversary Edition)          86       198440
# 3                                      Illuminaughty          64       234968
# 4  we fell in love in october / October Passed Me By          87       184153
# 5                                              punk2          48       137751
# 6                                       Cult Classic          53       107520
# 7     Piece By Piece - Music from the Motion Picture          50       128843
# 8                                 Unorthodox Jukebox          89       213826
# 9                                    T R A P S O U L          84       198294

# %%
# Preview artists
print("🎤 Top Artists (by followers):")
artists.nlargest(10, "followers")[["name", "genres", "popularity", "followers"]]
# Out:
# 🎤 Top Artists (by followers):
#                name                                          genres  \
# 926    Arijit Singh        [hindi pop, bollywood, desi, bangla pop]
# 1492   Taylor Swift                                              []
# 1024     Ed Sheeran                                      [soft pop]
# 1171  Billie Eilish                                              []
# 1        The Weeknd                                              []
# 427   Ariana Grande                                           [pop]
# 1165         Eminem                                  [rap, hip hop]
# 126       Bad Bunny  [reggaeton, trap latino, urbano latino, latin]
# 75            Drake                                           [rap]
# 463   Justin Bieber                                              []
#
#       popularity  followers
# 926           92  168225553
# 1492         100  148145192
# 1024          90  123750238
# 1171          93  120745503
# 1             96  115575232
# 427           95  108437388
# 1165          91  105865520
# 126           98  104932669
# 75            98  104906249
# 463           93   85869099

# %% [markdown]
# ## 6️⃣ Check Saved Files

# %%
# List saved files
print(f"📁 Files in {DATA_DIR}:\n")
for f in sorted(DATA_DIR.glob("*.parquet")):
    size_kb = f.stat().st_size / 1024
    print(f"   {f.name:30} {size_kb:>8.1f} KB")
# Out:
# 📁 Files in /Users/aryamaan/Desktop/Projects/spotim8_repo/data:
#
#    artists.parquet                   196.2 KB
#    library_wide.parquet             1644.4 KB
#    playlist_tracks.parquet           562.8 KB
#    playlists.parquet                 104.0 KB
#    track_artists.parquet             215.2 KB
#    tracks.parquet                    606.8 KB

# %% [markdown]
# ---
#
# ## ✅ Done!
#
# Your library is now saved locally. Next steps:
#
# 1. **Analyze**: Open `02_analyze_library.ipynb` for visualizations
# 2. **Playlist Analysis**: Open `03_playlist_analysis.ipynb` for genre clustering
# 3. **Re-sync**: Run this notebook again anytime to fetch new changes
#
# The data is cached, so future runs are fast!
